# %% [markdown]
# <a href="https://colab.research.google.com/github/yugantlamba/python/blob/main/python_for_generative_AI_Btech_core.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = 10

# %%
x
# Out:
# 10

# %%
mysub = "python"
mysub
# Out:
# 'python'

# %%
print(mysub)
# Out:
# python

# %%
_mycity = "Solan"
print(_mycity)
# Out:
# Solan

# %%
my_sub1 = "Generative AI"
print(my_sub1)
# Out:
# Generative AI

# %%
1my_sub = "Science"
print(1my_sub)
# Out:
#   File "/tmp/ipython-input-2475929071.py", line 1
#     1my_sub = "Science"
#     ^
# SyntaxError: invalid decimal literal

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x = 0
type(x)
# Out:
# int

# %%
y = 1.0
type(y)
# Out:
# float

# %%
z = 3+4j
type(z)
# Out:
# complex

# %%
#string --data in the form text
a = "solan"
type(a)
# Out:
# str

# %%
#boolean -- it is used to store value in the form of True and False
a = True
type(a)
# Out:
# bool

# %%
#None --it is define value means nothing
e = None
type(e)
# Out:
# NoneType

# %%
#single quotes
my_sub = 'Generative AI'
type(my_sub)
# Out:
# str

# %%
#double quotes
my_college = "shoolini university"
type(my_college)
# Out:
# str

# %%
#triple quotes
my_sentence = ''' this sentence is multiple lines,
this is also a string'''
type(my_sentence)
# Out:
# str

# %%
#find the length of string
my_sub = "Machine learning"
len(my_sub)
# Out:
# 16

# %%
my_sub[0]
# Out:
# 'M'

# %%
my_sub[-16]
# Out:
# 'M'

# %%
my_sub[-1]
# Out:
# 'g'

# %%
my_sub[4]
# Out:
# 'i'

# %%
my_sub
# Out:
# 'Machine learning'

# %%
my_sub[0:7:1]
# Out:
# 'Machine'

# %%
#concatenation--adding the string
first_name = "Amit"
last_name = "Kumar"
full_name = first_name +" "+ last_name
print(full_name)
# Out:
# Amit Kumar

# %%
#methods in string
#lower()--this method convert string into lower case
my_sub = "Machine Learning"
my_sub.lower()
# Out:
# 'machine learning'

# %%
lower(my_sub)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3174124106.py in <cell line: 0>()
# ----> 1 lower(my_sub)
#
# NameError: name 'lower' is not defined

# %%
#upper()--this method convert string into upper case
my_sub.upper()
# Out:
# 'MACHINE LEARNING'

# %%
#count()--count particular character of the string
my_sub = "Machine Learning"
my_sub.count("a")
# Out:
# 2

# %%
#list--it is sequence of item,every item separate by comma
#in list all item are enclosed by squarebracket
my_list = [98, 34, 56, "apple", True]
print(my_list)
# Out:
# [98, 34, 56, 'apple', True]

# %%
type(my_list)
# Out:
# list

# %%
#list homogenius as well hetrogenious
my_list = [10, 4, 5,6 ,7] #homogenius
type(my_list)
# Out:
# list

# %%
list1 = ["apple", True, 2, 3.14, None] #hetrogenious
type(list1)
# Out:
# list

# %%
#indexing in list-- location of item
#positive indexing
my_list =[23,45, 98, 12, 56]
my_list[0]
# Out:
# 23

# %%
len(my_list)
# Out:
# 5

# %%
my_list[4]
# Out:
# 56

# %%
#negative indexing
my_list =[23,45, 98, 12, 56]
my_list[-1]
# Out:
# 56

# %%
print(my_list[-2])
print(my_list[-3])
print(my_list[-4])
print(my_list[-5])
# Out:
# 12
# 98
# 45
# 23

# %%
#slicing in list
my_list = [2, 4, 7, 8, 9, 5, 3]
my_list[0:6:1]
# Out:
# [2, 4, 7, 8, 9, 5]

# %%
#list print in apposite direction
my_list[: :-1]
# Out:
# [3, 5, 9, 8, 7, 4, 2]

# %%
my_list[:]
# Out:
# [2, 4, 7, 8, 9, 5, 3]

# %%
#list is concatenated
list1 = [3, 4,5, 6]
list2 = [6, 7, 8, 9]
my_list = list1+list2
print(my_list)
# Out:
# [3, 4, 5, 6, 6, 7, 8, 9]

# %%
#function in list
my_list = [1, 2,3 ,4, 5,6]
min(my_list)
# Out:
# 1

# %%
max(my_list)
# Out:
# 6

# %%
sum(my_list)
# Out:
# 21

# %%
list1 = [8, 6, 9, 3, 10, 5, 2]
sorted(my_list)
# Out:
# [2, 3, 5, 6, 8, 9, 10]

# %%
list1
# Out:
# [8, 6, 9, 3, 10, 5, 2]

# %%
my_list = [8, 6, 9, 3, 10, 5, 2]
sorted(my_list, reverse = True)
# Out:
# [10, 9, 8, 6, 5, 3, 2]

# %%
my_list = [8, 6, 9, 3, 10, 5, 2]
my_list.sort(reverse =True)

# %%
my_list
# Out:
# [10, 9, 8, 6, 5, 3, 2]

# %%
my_list = [98, 45, 56, 78]
my_list.append(100)
my_list
# Out:
# [98, 45, 56, 78, 100]

# %%
list1 = [67, 56, 43, 78]
list2 = [90, 89, 76]
list1.extend(list2)
list1
# Out:
# [67, 56, 43, 78, 90, 89, 76]

# %%
#pop()--
my_list = [78, 45, 35, 78, 90]
my_list.pop()
# Out:
# 90

# %%
my_list
# Out:
# [78, 45, 35, 78]

# %%
my_list.pop(2)
# Out:
# 35

# %%
my_list
# Out:
# [78, 45, 78]

# %%
#remove
list1 = [67, 89, 45, 34]
list1.remove(89)

# %%
list1
# Out:
# [67, 45, 34]

# %%
my_dict = {"Name":"Kritika", "College":"shoolini"}
type(my_dict)
# Out:
# dict

# %%
print(my_dict)
# Out:
# {'Name': 'Kritika', 'College': 'shoolini'}

# %%
my_dict["Name"]
# Out:
# 'Kritika'

# %%
my_dict["College"]
# Out:
# 'shoolini'

# %%
#method in dictionary
#keys()--this method return keys of dictionary
list(my_dict.keys())
# Out:
# ['Name', 'College']

# %%
#values()--this method return values of dictionary
list(my_dict.values())
# Out:
# ['Kritika', 'shoolini']

# %%
#items()--this method return item of the dictionary
list(my_dict.items())
# Out:
# [('Name', 'Kritika'), ('College', 'shoolini')]

# %%
#get()--this method find value and take key as a argument
my_dict.get("Name")
# Out:
# 'Kritika'

# %%
print(my_dict.get("Age", "Age is not present"))
# Out:
# Age is not present

# %%
#update()--this method update dictionary and take dictionary as argument
my_dict.update({"Age":20})
print(my_dict)
# Out:
# {'Name': 'Kritika', 'College': 'shoolini', 'Age': 20}

# %%
my_dict.update({"Name":"Jagat"})
print(my_dict)
# Out:
# {'Name': 'Jagat', 'College': 'shoolini', 'Age': 20}

# %%
#conditional statement
#if --this statement execute when condition is true
#elif--this statement execute when condition is true
#else--this statement execute when if and elif are not execute
age = int(input("enter your age: "))
if age>60:
  print("You are too old for marry")
elif age<18:
  print("You are too young for marry")
else:
  print("we will find perfact match for you")
# Out:
# enter your age: 12
# You are too young for marry

# %%
#loop helps execute block of repeatedly
#for loop--this loop apply on sequence(list, string, tuple)
my_sub = "Python"
print(my_sub[0])
print(my_sub[1])
print(my_sub[2])
print(my_sub[3])
print(my_sub[4])
print(my_sub[5])
# Out:
# P
# y
# t
# h
# o
# n

# %%
my_sub = "python"
for i in my_sub:
  print(i)
# Out:
# p
# y
# t
# h
# o
# n

# %%
for i in range(len(my_sub)):
  print(my_sub[i], "->", i)
# Out:
# p -> 0
# y -> 1
# t -> 2
# h -> 3
# o -> 4
# n -> 5

# %%
my_list = [89, 76, 45, 34]
for i in my_list:
  print(i)
# Out:
# 89
# 76
# 45
# 34

# %%
#while loop--this loop execute until condition is true
i= 0
while i<5:
  print(i)
  i+=1
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#loop control statement
#break-- this statement break the loop
i = 0
while i<5:
  i+=1
  if i == 3:
    break
  else:
    print(i)
# Out:
# 1
# 2

# %%
#continue statement--skip current iteration
i = 0
while i<5:
  i+=1
  if i==3:
    continue
    #print(i)
  else:
    print(i)
# Out:
# 1
# 2
# 4
# 5

# %%
#pass statement --only pass cursor
i = 0
while i<5:
  i+=1
  if i==3:
    pass
    print(i)
  else:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
#user defined function without argument
def add():
  a = int(input("Enter first number: "))
  b = int(input("Enter second number:"))
  return a+b

# %%
print(add())
# Out:
# Enter first number: 10
# Enter second number:5
# 15

# %%
#positional argument
def Calculation(a, b):
  print("addition: ", a+b)
  print("Subtraction :", a-b)
  print("Multiplication: ", a*b)
  print("Division :", a/b)
  return "Calculation are complete"

# %%
print(Calculation(10, 5))
# Out:
# addition:  15
# Subtraction : 5
# Multiplication:  50
# Division : 2.0
# Calculation are complete

# %%
#default argument
def area_perimeter(width = 8, height = 4):
  area = width*height
  perimeter = 2*(width +height)
  return "Area is", area, "and perimeter is", perimeter

# %%
print(area_perimeter(10, 8))
# Out:
# ('Area is', 80, 'and perimeter is', 36)

# %%
#keyword argument
def interest(p, r, t):
  i = (p*r*t)/100
  return i

# %%
print(interest(t = 2, p = 1000, r= 10))
# Out:
# 200.0

# %%
#mixed argument
print(interest(1000, t = 2, r = 10))
# Out:
# 200.0

# %%
print(interest(p = 1000, r = 10, 2))
# Out:
#   File "/tmp/ipython-input-1496732972.py", line 1
#     print(interest(p = 1000, r = 10, 2))
#                                       ^
# SyntaxError: positional argument follows keyword argument

# %%
#non keyword variable length argument
def test(*args):
  print(args)
  print(len(args))
  print(type(args))

# %%
test(1, 2,3, 4,5, 6,7)
# Out:
# (1, 2, 3, 4, 5, 6, 7)
# 7
# <class 'tuple'>

# %%
def sum_number(*args):
  sum = 0
  for num in args:
    sum+=num
  return sum

# %%
sum_number(4, 5, 6, 7)
# Out:
# 22

# %%
#keyword variable length argument
def test(**kwargs):
  print(kwargs)
  print(len(kwargs))
  print(type(kwargs))

# %%
test(a = 10, b = 20, c = 30)
# Out:
# {'a': 10, 'b': 20, 'c': 30}
# 3
# <class 'dict'>

# %%
import numpy as np

# %%
oned_array = np.array([1, 2, 3])
print(oned_array)
# Out:
# [1 2 3]

# %%
row_vector = np.array([[1, 2, 3]])
print(row_vector)
# Out:
# [[1 2 3]]

# %%
column_vector = row_vector.transpose()
print(column_vector)
# Out:
# [[1]
#  [2]
#  [3]]

# %%
print(oned_array)
# Out:
# [1 2 3]

# %%
#ndim--dimension
oned_array.ndim
# Out:
# 1

# %%
row_vector
# Out:
# array([[1, 2, 3]])

# %%
row_vector.ndim
# Out:
# 2

# %%
print(row_vector)
# Out:
# [[1 2 3]]

# %%
print(row_vector.ndim)
print(row_vector.shape)
print(row_vector.size)
print(row_vector.transpose())
# Out:
# 2
# (1, 3)
# 3
# [[1]
#  [2]
#  [3]]

# %%
rank_one_vector = np.array([1, 2, 3])
print(rank_one_vector)
# Out:
# [1 2 3]

# %%
twod_array = np.array([[1, 2, 3],[4, 5, 6]])
print(twod_array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
#indexing
print(twod_array[0][1])
# Out:
# 2

# %%
print(twod_array[1][2])
# Out:
# 6

# %%
print(twod_array)
# Out:
# [[1 2 3]
#  [4 5 6]]

# %%
print(twod_array[0:,0:2])
# Out:
# [[1 2]
#  [4 5]]

# %%
mat1 = np.matrix("1, 2, 3;4, 5, 6;7, 8, 9")
print(mat1)
# Out:
# [[1 2 3]
#  [4 5 6]
#  [7 8 9]]

# %%
random_array = np.random.random((3, 3))
print(random_array)
# Out:
# [[0.63446121 0.0837939  0.15107758]
#  [0.82039292 0.91825149 0.47926521]
#  [0.02743014 0.28666014 0.40375273]]

# %%
randint_array = np.random.randint(1, 10, (3, 3))
print(randint_array)
# Out:
# [[1 8 5]
#  [4 1 2]
#  [8 9 6]]

# %%
data = np.array([1,2, 3, 4])
power_data = np.power(data, 2)
print(power_data)
# Out:
# [ 1  4  9 16]

# %%
print(data)
# Out:
# [1 2 3 4]

# %%
exp_data = np.exp(data)
print(exp_data)
# Out:
# [ 2.71828183  7.3890561  20.08553692 54.59815003]

# %%
log_data = np.log(data)
print(log_data)
# Out:
# [0.         0.69314718 1.09861229 1.38629436]

# %%
log2_data = np.log2(data)
print(log2_data)
# Out:
# [0.        1.        1.5849625 2.       ]

# %%
log10_data = np.log10(data)
print(log10_data)
# Out:
# [0.         0.30103    0.47712125 0.60205999]

# %%
zeros_array = np.zeros((3, 3),dtype =int )
print(zeros_array)
# Out:
# [[0 0 0]
#  [0 0 0]
#  [0 0 0]]

# %%
ones_array = np.ones((2, 3),dtype = int)
print(ones_array)
# Out:
# [[1 1 1]
#  [1 1 1]]

# %%
#matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
#line plot
xpoint = np.array([1, 3])
ypoint = np.array([2, 4])
plt.plot(xpoint, ypoint)
plt.show()

# %%
cgpa = np.array([6, 6.8, 7, 7.5, 8, 8.4, 8.8, 9, 9.5, 10])
package = np.array([4, 5.2, 5.5, 6, 6.5, 7, 7.5, 8, 8.5, 9])
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}
plt.plot(cgpa,package,"*:g", ms =15,mec = "orange",linewidth = 2)
plt.xlabel("cgpa",fontdict=font2)
plt.ylabel("package",fontdict=font2)
plt.title("CGPA VS PACKAGE",fontdict=font1)
plt.grid()
plt.show()

# %%
#bar plot--it work on numerical as well categorical data
import matplotlib.pyplot as plt
import numpy as np
fruit = np.array(["Apple", "Banana","Orange","Watermelon"])
fruit_number = np.array([100, 80,120, 50])
color = ["red","yellow","orange","green"]
plt.bar(fruit, fruit_number, color = color)
plt.show()

# %%
fruit = np.array(["Apple", "Banana","Orange","Watermelon"])
fruit_number = np.array([100, 80,120, 50])
color = ["red","yellow","orange","green"]
plt.barh(fruit, fruit_number, color = color)
plt.show()

# %%
#pie plot
x = np.array([25, 35, 20, 20])
my_labels = np.array(["Apple", "Banana", "Orange", "Watermelon"])
my_explode = np.array([0.2, 0, 0, 0])
plt.pie(x, labels = my_labels,explode = my_explode)
plt.legend(title = "Fruit",loc = "upper right")
plt.show()

# %%
#scatter plot--it is work on numerical data
x = np.array([1, 2, 3, 4, 5, 6, 7, 8])
y = np.array([200, 180, 160, 150, 130, 120, 110, 100])
plt.xlabel("Age of car")
plt.ylabel("Speed of car")
plt.title("Scatter plot")
plt.scatter(x, y)
plt.show()

# %%
#histogram --A histogram shows frequency distribution
x = np.random.randint(40, 100, (1, 200))
x = x.flatten()
print(x)
plt.xlabel("Marks of students")
plt.ylabel("Number of students")
plt.title("Histogram plot of students marks")
plt.hist(x,bins = 10)
plt.show()
# Out:
# [44 60 89 53 97 48 40 74 70 80 61 97 48 60 61 49 53 98 96 51 74 42 86 64
#  41 79 75 88 59 92 55 86 79 60 88 62 65 98 70 59 65 51 53 81 99 87 99 91
#  46 48 55 62 81 64 78 88 44 61 66 82 95 94 82 79 96 65 98 43 71 83 41 60
#  96 77 81 98 48 95 85 40 72 71 61 67 66 44 56 79 67 89 62 56 45 78 57 78
#  45 50 91 41 86 47 76 49 77 86 65 46 61 84 80 76 55 74 75 80 43 99 57 84
#  83 47 57 49 43 51 89 60 45 92 45 40 51 59 82 78 95 92 89 81 45 48 91 87
#  44 79 58 88 67 89 67 48 43 60 75 81 90 43 47 73 93 52 64 88 81 91 83 42
#  53 79 94 50 54 44 93 78 97 97 68 96 93 84 79 78 57 71 49 68 41 79 62 56
#  62 83 59 78 56 99 65 73]

# %%
import pandas as pd

# %%
my_series = pd.Series(["Apple", "Banana", "Orange", "Watermelon"], name="Fruit")
my_series
# Out:
# 0         Apple
# 1        Banana
# 2        Orange
# 3    Watermelon
# Name: Fruit, dtype: object

# %%
list_of_list = [["Amar",15],["Akbar",14], ["Anthony",13]]
df = pd.DataFrame(list_of_list, columns = ["Name", "Age"] )
df
# Out:
#       Name  Age
# 0     Amar   15
# 1    Akbar   14
# 2  Anthony   13

# %%
import pandas as pd
df = pd.read_csv("/content/drive/MyDrive/data/imdb_data.csv")
df
# Out:
#         id                              belongs_to_collection    budget  \
# 0        1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1        2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2        3                                                NaN   3300000
# 3        4                                                NaN   1200000
# 4        5                                                NaN         0
# ...    ...                                                ...       ...
# 2995  2996                                                NaN         0
# 2996  2997                                                NaN         0
# 2997  2998                                                NaN  65000000
# 2998  2999                                                NaN  42000000
# 2999  3000                                                NaN  35000000
#
#                                                  genres  \
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# 2995  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# 0                                   NaN  tt2637294                en
# 1                                   NaN  tt0368933                en
# 2     http://sonyclassics.com/whiplash/  tt2582802                en
# 3            http://kahaanithefilm.com/  tt1821480                hi
# 4                                   NaN  tt1380152                ko
# ...                                 ...        ...               ...
# 2995                                NaN  tt0109403                en
# 2996                                NaN  tt2364975                sv
# 2997                                NaN  tt0116908                en
# 2998     http://www.alongcamepolly.com/  tt0343135                en
# 2999   http://www.abductionthefilm.com/  tt1600195                en
#
#                                 original_title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                         마린보이
# ...                                        ...
# 2995                                   Chasers
# 2996                               Vi är bäst!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                overview  popularity  ...  \
# 0     When Lou, who has become the "father of the In...    6.575393  ...
# 1     Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2     Under the direction of a ruthless instructor, ...   64.299990  ...
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 4     Marine Boy is the story of a former national s...    1.148070  ...
# ...                                                 ...         ...  ...
# 2995  Military men Rock Reilly and Eddie Devane are ...    9.853270  ...
# 2996  Three girls in 1980s Stockholm decide to form ...    3.727996  ...
# 2997  Samantha Caine, suburban homemaker, is the ide...   14.482345  ...
# 2998  Reuben Feffer is a guy who's spent his entire ...   15.725542  ...
# 2999  A young man sets out to uncover the truth abou...   10.512109  ...
#
#      release_date runtime                                   spoken_languages  \
# 0         2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1          8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2        10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3          3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 4          2/5/09   118.0           [{'iso_639_1': 'ko', 'name': '한국어/조선말'}]
# ...           ...     ...                                                ...
# 2995      4/22/94   102.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2996      3/28/13   102.0           [{'iso_639_1': 'sv', 'name': 'svenska'}]
# 2997     10/11/96   120.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2998      1/16/04    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2999      9/22/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 0     Released  The Laws of Space and Time are About to be Vio...
# 1     Released  It can take a lifetime to find true love; she'...
# 2     Released    The road to greatness can take you to the edge.
# 3     Released                                                NaN
# 4     Released                                                NaN
# ...        ...                                                ...
# 2995  Released  It was supposed to be a routine prisoner trans...
# 2996  Released                                                NaN
# 2997  Released               What's forgotten is not always gone.
# 2998  Released  For the most cautious man on Earth, life is ab...
# 2999  Released          They stole his life. He's taking it back.
#
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                Keywords  \
# 0     [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1     [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2     [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 4                                                   NaN
# ...                                                 ...
# 2995  [{'id': 378, 'name': 'prison'}, {'id': 572, 'n...
# 2996  [{'id': 1192, 'name': 'sweden'}, {'id': 4470, ...
# 2997  [{'id': 441, 'name': 'assassination'}, {'id': ...
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 0     [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1     [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2     [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 4     [{'cast_id': 3, 'character': 'Chun-soo', 'cred...
# ...                                                 ...
# 2995  [{'cast_id': 2, 'character': 'Rock Reilly', 'c...
# 2996  [{'cast_id': 5, 'character': 'Bobo', 'credit_i...
# 2997  [{'cast_id': 10, 'character': 'Samantha Caine ...
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 0     [{'credit_id': '59ac067c92514107af02c8c8', 'de...   12314651
# 1     [{'credit_id': '52fe43fe9251416c7502563d', 'de...   95149435
# 2     [{'credit_id': '54d5356ec3a3683ba0000039', 'de...   13092000
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 4     [{'credit_id': '52fe464b9251416c75073b43', 'de...    3923970
# ...                                                 ...        ...
# 2995  [{'credit_id': '52fe4494c3a368484e02ac7d', 'de...    1596687
# 2996  [{'credit_id': '5716b72ac3a3686678012c84', 'de...     180590
# 2997  [{'credit_id': '52fe443a9251416c7502d579', 'de...   89456761
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [3000 rows x 23 columns]

# %%
#find the number of rows and columns
df.shape
# Out:
# (3000, 23)

# %%
#fetch data from top
df.head(2)
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
#
#                                               genres homepage    imdb_id  \
# 0                     [{'id': 35, 'name': 'Comedy'}]      NaN  tt2637294
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  tt0368933
#
#   original_language                            original_title  \
# 0                en                    Hot Tub Time Machine 2
# 1                en  The Princess Diaries 2: Royal Engagement
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
#
#   release_date runtime                          spoken_languages    status  \
# 0      2/20/15    93.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1       8/6/04   113.0  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                              tagline  \
# 0  The Laws of Space and Time are About to be Vio...
# 1  It can take a lifetime to find true love; she'...
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
#
# [2 rows x 23 columns]

# %%
#fetch data from bottom
df.tail(2)
# Out:
#         id belongs_to_collection    budget  \
# 2998  2999                   NaN  42000000
# 2999  3000                   NaN  35000000
#
#                                                  genres  \
# 2998  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                               homepage    imdb_id original_language  \
# 2998    http://www.alongcamepolly.com/  tt0343135                en
# 2999  http://www.abductionthefilm.com/  tt1600195                en
#
#         original_title                                           overview  \
# 2998  Along Came Polly  Reuben Feffer is a guy who's spent his entire ...
# 2999         Abduction  A young man sets out to uncover the truth abou...
#
#       popularity  ... release_date runtime  \
# 2998   15.725542  ...      1/16/04    90.0
# 2999   10.512109  ...      9/22/11   106.0
#
#                               spoken_languages    status  \
# 2998  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 2999  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                                 tagline             title  \
# 2998  For the most cautious man on Earth, life is ab...  Along Came Polly
# 2999          They stole his life. He's taking it back.         Abduction
#
#                                                Keywords  \
# 2998  [{'id': 966, 'name': 'beach'}, {'id': 2676, 'n...
# 2999  [{'id': 591, 'name': 'cia'}, {'id': 822, 'name...
#
#                                                    cast  \
# 2998  [{'cast_id': 8, 'character': 'Reuben Feffer', ...
# 2999  [{'cast_id': 2, 'character': 'Nathan Harper', ...
#
#                                                    crew    revenue
# 2998  [{'credit_id': '556f817b9251410866000a63', 'de...  171963386
# 2999  [{'credit_id': '5391990d0e0a260fb5001629', 'de...   82087155
#
# [2 rows x 23 columns]

# %%
#fetch data point randomly
df.sample(10)
# Out:
#         id                              belongs_to_collection    budget  \
# 267    268  [{'id': 182813, 'name': 'Clerks Collection', '...     27000
# 2593  2594  [{'id': 937, 'name': 'The Pink Panther (Origin...  25000000
# 75      76  [{'id': 230161, 'name': 'Fright Night (Reboot)...  17000000
# 1701  1702                                                NaN         0
# 1699  1700                                                NaN  20000000
# 332    333                                                NaN   5000000
# 2182  2183                                                NaN  70000000
# 1770  1771                                                NaN         0
# 786    787  [{'id': 437451, 'name': 'Cinderella Story Coll...  19000000
# 998    999  [{'id': 228887, 'name': 'Daddy Day Camp Collec...  60000000
#
#                                                  genres  \
# 267                      [{'id': 35, 'name': 'Comedy'}]
# 2593                     [{'id': 35, 'name': 'Comedy'}]
# 75    [{'id': 27, 'name': 'Horror'}, {'id': 35, 'nam...
# 1701                [{'id': 99, 'name': 'Documentary'}]
# 1699  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 332   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2182  [{'id': 18, 'name': 'Drama'}, {'id': 10752, 'n...
# 1770  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 786                      [{'id': 35, 'name': 'Comedy'}]
# 998   [{'id': 35, 'name': 'Comedy'}, {'id': 10751, '...
#
#                                                homepage    imdb_id  \
# 267                http://www.miramax.com/movie/clerks/  tt0109445
# 2593                                                NaN  tt0108187
# 75                  http://www.welcometofrightnight.com  tt1438176
# 1701                                                NaN  tt3013258
# 1699                          http://www.disturbia.com/  tt0486822
# 332        http://www.greenestreetfilms.com/f_bill.html  tt0790623
# 2182                                                NaN  tt0251114
# 1770                                                NaN  tt0114663
# 786   http://www2.warnerbros.com/acinderellastory/in...  tt0356470
# 998                                                 NaN  tt0317303
#
#      original_language            original_title  \
# 267                 en                    Clerks
# 2593                en   Son of the Pink Panther
# 75                  en              Fright Night
# 1701                fr  Sur le chemin de l'école
# 1699                en                 Disturbia
# 332                 en                 Meet Bill
# 2182                en                Hart's War
# 1770                en              Three Wishes
# 786                 en        A Cinderella Story
# 998                 en            Daddy Day Care
#
#                                                overview  popularity  ...  \
# 267   Convenience and video store clerks Dante and R...   10.513367  ...
# 2593  The eighth and last of the Pink Panther series...    3.372523  ...
# 75    A teenager suspects his new neighbour is a vam...    9.665251  ...
# 1701  These children live in the four corners of the...    1.784682  ...
# 1699  Kale is a 17-year-old placed under house arres...   18.006896  ...
# 332   A mild-mannered bank executive (Aaron Eckhart)...    6.226054  ...
# 2182  Fourth-generation Army Col. William McNamara i...   14.116474  ...
# 1770  While Jane Holman (Mastrantonio) is driving wi...   11.002046  ...
# 786   Sam Montgomery is a tomboyish, unpopular girl ...    8.385361  ...
# 998   Two men get laid off and have to become stay-a...    6.504927  ...
#
#      release_date runtime                                   spoken_languages  \
# 267       9/13/94    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2593       1/1/93    93.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 75        8/18/11   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1701      9/25/13    77.0          [{'iso_639_1': 'fr', 'name': 'Français'}]
# 1699      4/12/07   105.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 332        9/7/07    97.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2182      2/15/02   125.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1770     10/27/95   115.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 786       7/10/04    95.0  [{'iso_639_1': 'cs', 'name': 'Český'}, {'iso_6...
# 998        5/3/03    92.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#         status                                            tagline  \
# 267   Released  Just because they serve you doesn't mean they ...
# 2593  Released     Inspector Clouseau's biggest mistake lives on!
# 75    Released   You can't run from evil when it lives next door.
# 1701  Released                                                NaN
# 1699  Released  The quieter the street, the darker the secrets...
# 332   Released                   A comedy about someone you know.
# 2182  Released                      Beyond Courage, Beyond Honor.
# 1770  Released         If you really believe, magic will find you
# 786   Released           Once upon a time... can happen any time.
# 998   Released                                  Who's your daddy?
#
#                         title  \
# 267                    Clerks
# 2593  Son of the Pink Panther
# 75               Fright Night
# 1701     On the Way to School
# 1699                Disturbia
# 332                 Meet Bill
# 2182               Hart's War
# 1770             Three Wishes
# 786        A Cinderella Story
# 998            Daddy Day Care
#
#                                                Keywords  \
# 267   [{'id': 1361, 'name': 'salesclerk'}, {'id': 30...
# 2593                                                NaN
# 75    [{'id': 813, 'name': 'sunrise'}, {'id': 3133, ...
# 1701                                                NaN
# 1699  [{'id': 1930, 'name': 'kidnapping'}, {'id': 65...
# 332   [{'id': 596, 'name': 'adultery'}, {'id': 985, ...
# 2182  [{'id': 577, 'name': 'black people'}, {'id': 1...
# 1770  [{'id': 1480, 'name': 'baseball'}, {'id': 1301...
# 786   [{'id': 931, 'name': 'jealousy'}, {'id': 995, ...
# 998   [{'id': 271, 'name': 'competition'}, {'id': 38...
#
#                                                    cast  \
# 267   [{'cast_id': 7, 'character': 'Dante Hicks', 'c...
# 2593  [{'cast_id': 5, 'character': 'Gendarme Jacques...
# 75    [{'cast_id': 9, 'character': 'Charley Brewster...
# 1701  [{'cast_id': 5, 'character': 'Elle-m√™me', 'cr...
# 1699  [{'cast_id': 1, 'character': 'Kale Brecht', 'c...
# 332   [{'cast_id': 8, 'character': 'Bill', 'credit_i...
# 2182  [{'cast_id': 19, 'character': 'Col. William A....
# 1770  [{'cast_id': 5, 'character': 'Jack McCloud', '...
# 786   [{'cast_id': 1, 'character': 'Sam Montgomery',...
# 998   [{'cast_id': 1, 'character': 'Charlie Hinton',...
#
#                                                    crew    revenue
# 267   [{'credit_id': '52fe434ac3a36847f8049259', 'de...    3151130
# 2593  [{'credit_id': '52fe470ec3a36847f8121135', 'de...    2438031
# 75    [{'credit_id': '52fe4956c3a36847f8194f53', 'de...   24922237
# 1701  [{'credit_id': '52fe4de89251416c7514504d', 'de...       7424
# 1699  [{'credit_id': '55be22ab9251413e58004651', 'de...  117760134
# 332   [{'credit_id': '52fe45519251416c7505268f', 'de...     346592
# 2182  [{'credit_id': '52fe438e9251416c75015179', 'de...   32287044
# 1770  [{'credit_id': '52fe474fc3a36847f812e7fd', 'de...    7025496
# 786   [{'credit_id': '52fe441a9251416c75028d57', 'de...   70067909
# 998   [{'credit_id': '52fe43a69251416c75018b8d', 'de...  164433867
#
# [10 rows x 23 columns]

# %%
#find the information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
#  14  runtime                2998 non-null   float64
#  15  spoken_languages       2980 non-null   object
#  16  status                 3000 non-null   object
#  17  tagline                2403 non-null   object
#  18  title                  3000 non-null   object
#  19  Keywords               2724 non-null   object
#  20  cast                   2987 non-null   object
#  21  crew                   2984 non-null   object
#  22  revenue                3000 non-null   int64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 539.2+ KB

# %%
#How does the data looklike mathematically
df.describe()
# Out:
#                 id        budget   popularity      runtime       revenue
# count  3000.000000  3.000000e+03  3000.000000  2998.000000  3.000000e+03
# mean   1500.500000  2.253133e+07     8.463274   107.856571  6.672585e+07
# std     866.169729  3.702609e+07    12.104000    22.086434  1.375323e+08
# min       1.000000  0.000000e+00     0.000001     0.000000  1.000000e+00
# 25%     750.750000  0.000000e+00     4.018053    94.000000  2.379808e+06
# 50%    1500.500000  8.000000e+06     7.374861   104.000000  1.680707e+07
# 75%    2250.250000  2.900000e+07    10.890983   118.000000  6.891920e+07
# max    3000.000000  3.800000e+08   294.337037   338.000000  1.519558e+09

# %%
#find the number of columns
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
#find the duplicate value
print(df.duplicated().sum())
# Out:
# 0

# %%
#find the null value
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %%
#indexing and slicing
df["title"]
# Out:
# 0                         Hot Tub Time Machine 2
# 1       The Princess Diaries 2: Royal Engagement
# 2                                       Whiplash
# 3                                        Kahaani
# 4                                     Marine Boy
#                           ...
# 2995                                     Chasers
# 2996                            We Are the Best!
# 2997                     The Long Kiss Goodnight
# 2998                            Along Came Polly
# 2999                                   Abduction
# Name: title, Length: 3000, dtype: object

# %%
df[["title", "budget","revenue", "original_language"]]
# Out:
#                                          title    budget    revenue  \
# 0                       Hot Tub Time Machine 2  14000000   12314651
# 1     The Princess Diaries 2: Royal Engagement  40000000   95149435
# 2                                     Whiplash   3300000   13092000
# 3                                      Kahaani   1200000   16000000
# 4                                   Marine Boy         0    3923970
# ...                                        ...       ...        ...
# 2995                                   Chasers         0    1596687
# 2996                          We Are the Best!         0     180590
# 2997                   The Long Kiss Goodnight  65000000   89456761
# 2998                          Along Came Polly  42000000  171963386
# 2999                                 Abduction  35000000   82087155
#
#      original_language
# 0                   en
# 1                   en
# 2                   en
# 3                   hi
# 4                   ko
# ...                ...
# 2995                en
# 2996                sv
# 2997                en
# 2998                en
# 2999                en
#
# [3000 rows x 4 columns]

# %%
df[0:4]
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# 2  http://sonyclassics.com/whiplash/  tt2582802                en
# 3         http://kahaanithefilm.com/  tt1821480                hi
#
#                              original_title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
#
#                                             overview  popularity  ...  \
# 0  When Lou, who has become the "father of the In...    6.575393  ...
# 1  Mia Thermopolis is now a college graduate and ...    8.248895  ...
# 2  Under the direction of a ruthless instructor, ...   64.299990  ...
# 3  Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
#
#   release_date runtime                                   spoken_languages  \
# 0      2/20/15    93.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1       8/6/04   113.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 2     10/10/14   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3       3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
#
#      status                                            tagline  \
# 0  Released  The Laws of Space and Time are About to be Vio...
# 1  Released  It can take a lifetime to find true love; she'...
# 2  Released    The road to greatness can take you to the edge.
# 3  Released                                                NaN
#
#                                       title  \
# 0                    Hot Tub Time Machine 2
# 1  The Princess Diaries 2: Royal Engagement
# 2                                  Whiplash
# 3                                   Kahaani
#
#                                             Keywords  \
# 0  [{'id': 4379, 'name': 'time travel'}, {'id': 9...
# 1  [{'id': 2505, 'name': 'coronation'}, {'id': 42...
# 2  [{'id': 1416, 'name': 'jazz'}, {'id': 1523, 'n...
# 3  [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
#
#                                                 cast  \
# 0  [{'cast_id': 4, 'character': 'Lou', 'credit_id...
# 1  [{'cast_id': 1, 'character': 'Mia Thermopolis'...
# 2  [{'cast_id': 5, 'character': 'Andrew Neimann',...
# 3  [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
#
#                                                 crew   revenue
# 0  [{'credit_id': '59ac067c92514107af02c8c8', 'de...  12314651
# 1  [{'credit_id': '52fe43fe9251416c7502563d', 'de...  95149435
# 2  [{'credit_id': '54d5356ec3a3683ba0000039', 'de...  13092000
# 3  [{'credit_id': '52fe48779251416c9108d6eb', 'de...  16000000
#
# [4 rows x 23 columns]

# %%
df.iloc[0:4,0:3]
# Out:
#    id                              belongs_to_collection    budget
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000

# %%
df.loc[0:4,["title","budget","revenue"]]
# Out:
#                                       title    budget   revenue
# 0                    Hot Tub Time Machine 2  14000000  12314651
# 1  The Princess Diaries 2: Royal Engagement  40000000  95149435
# 2                                  Whiplash   3300000  13092000
# 3                                   Kahaani   1200000  16000000
# 4                                Marine Boy         0   3923970

# %%
df["original_language"].unique()
# Out:
# array(['en', 'hi', 'ko', 'sr', 'fr', 'it', 'nl', 'zh', 'es', 'cs', 'ta',
#        'cn', 'ru', 'tr', 'ja', 'fa', 'sv', 'de', 'te', 'pt', 'mr', 'da',
#        'fi', 'el', 'ur', 'he', 'no', 'ar', 'nb', 'ro', 'vi', 'pl', 'hu',
#        'ml', 'bn', 'id'], dtype=object)

# %%
hindi_movie = df[df["original_language"]=="hi"]
hindi_movie
# Out:
#         id                              belongs_to_collection    budget  \
# 3        4                                                NaN   1200000
# 213    214                                                NaN   6700000
# 371    372                                                NaN  13100000
# 401    402                                                NaN   3000000
# 419    420                                                NaN   3750000
# 481    482                                                NaN  10500000
# 585    586                                                NaN  10400000
# 627    628                                                NaN  16000000
# 671    672                                                NaN   6400000
# 695    696                                                NaN         1
# 771    772                                                NaN   9000000
# 840    841                                                NaN  10721568
# 848    849                                                NaN   6400000
# 970    971                                                NaN   4200000
# 1004  1005                                                NaN   1000000
# 1491  1492                                                NaN   5500000
# 1572  1573                                                NaN   9100000
# 1640  1641                                                NaN   4600000
# 1656  1657                                                NaN  18000000
# 1694  1695                                                NaN    521873
# 1719  1720                                                NaN   4437508
# 1729  1730                                                NaN   5200000
# 1732  1733  [{'id': 419784, 'name': 'Masti Collection', 'p...   5500000
# 1766  1767                                                NaN         0
# 1948  1949                                                NaN         0
# 1987  1988                                                NaN         0
# 1989  1990  [{'id': 20970, 'name': 'Sarkar Collection', 'p...   1900000
# 2239  2240  [{'id': 44976, 'name': 'Dhoom Series', 'poster...  19500000
# 2251  2252                                                NaN       130
# 2287  2288                                                NaN  18000000
# 2353  2354                                                NaN   8376800
# 2390  2391                                                NaN   7500000
# 2436  2437                                                NaN   4300000
# 2480  2481                                                NaN   6400000
# 2538  2539                                                NaN   6900000
# 2563  2564                                                NaN   7400000
# 2567  2568                                                NaN  11000000
# 2807  2808                                                NaN   5300000
# 2828  2829                                                NaN  19500000
# 2857  2858                                                NaN   5400000
# 2859  2860  [{'id': 286951, 'name': 'Singham Collection', ...   3062000
# 2959  2960                                                NaN   2300000
#
#                                                  genres  \
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 213                      [{'id': 28, 'name': 'Action'}]
# 371   [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 401   [{'id': 18, 'name': 'Drama'}, {'id': 36, 'name...
# 419   [{'id': 35, 'name': 'Comedy'}, {'id': 10769, '...
# 481   [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 585                       [{'id': 18, 'name': 'Drama'}]
# 627   [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 671   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 695   [{'id': 10749, 'name': 'Romance'}, {'id': 53, ...
# 771   [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 840                       [{'id': 18, 'name': 'Drama'}]
# 848   [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 970   [{'id': 10749, 'name': 'Romance'}, {'id': 28, ...
# 1004  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1491  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
# 1572  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 1640  [{'id': 36, 'name': 'History'}, {'id': 28, 'na...
# 1656  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 1694  [{'id': 53, 'name': 'Thriller'}, {'id': 80, 'n...
# 1719  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1729  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 1732  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1766  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 1948  [{'id': 35, 'name': 'Comedy'}, {'id': 80, 'nam...
# 1987  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 1989  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2239  [{'id': 28, 'name': 'Action'}, {'id': 80, 'nam...
# 2251  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 2287  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
# 2353  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...
# 2390  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2436  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2480  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 2538  [{'id': 10749, 'name': 'Romance'}, {'id': 18, ...
# 2563  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 2567  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 2807  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 2828  [{'id': 10752, 'name': 'War'}, {'id': 36, 'nam...
# 2857                   [{'id': 53, 'name': 'Thriller'}]
# 2859  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 2959  [{'id': 18, 'name': 'Drama'}, {'id': 35, 'name...
#
#                                                homepage    imdb_id  \
# 3                            http://kahaanithefilm.com/  tt1821480
# 213                                                 NaN  tt2077833
# 371                     http://www.thankyouthefilm.com/  tt1720254
# 401                                                 NaN  tt0319736
# 419                       http://www.atithithefilm.com/  tt1578116
# 481                        http://www.cc2c-thefilm.com/  tt1091229
# 585                                                 NaN  tt5074352
# 627   http://www.yashrajfilms.com/Movies/MovieIndivi...  tt3495026
# 671     http://www.anjaanaanjaani.erosentertainment.com  tt1499201
# 695                                                 NaN  tt0374271
# 771                          http://kaminey.utvnet.com/  tt1274295
# 840              https://www.facebook.com/foxstarhindi/  tt5286444
# 848                                                 NaN  tt2359810
# 970                                                 NaN  tt3142232
# 1004                                                NaN  tt2350496
# 1491                                                NaN  tt3767372
# 1572                    http://www.rememberghajini.com/  tt1166100
# 1640                                                NaN  tt2356180
# 1656  http://www.chennaiexp2013.com/chennaiexpress.aspx  tt2112124
# 1694                                                NaN  tt5662932
# 1719  http://www.utvgroup.com/motion-pictures/coming...  tt2082197
# 1729                                                NaN  tt0164538
# 1732                                                NaN  tt2476154
# 1766                                                NaN  tt0290326
# 1948                                                NaN  tt0476805
# 1987                                                NaN  tt0347304
# 1989                                                NaN  tt0432047
# 2239                                                NaN  tt1833673
# 2251                                                NaN  tt1729637
# 2287                                                NaN  tt2979920
# 2353                        http://www.jodhaaakbar.com/  tt0449994
# 2390                http://www.khattameethathefilm.com/  tt1455811
# 2436                                                NaN  tt5946128
# 2480                                                NaN  tt2168910
# 2538                                                NaN  tt0151150
# 2563                                                NaN  tt0449999
# 2567                                                NaN  tt2424988
# 2807                                                NaN  tt0439662
# 2828                                                NaN  tt3735246
# 2857                                                NaN  tt2855648
# 2859                                                NaN  tt1948150
# 2959                                                NaN  tt1093370
#
#      original_language              original_title  \
# 3                   hi                     Kahaani
# 213                 hi                 राउडी राठौर
# 371                 hi                   Thank You
# 401                 hi  The Legend of Bhagat Singh
# 419                 hi        Atithi Tum Kab Jaoge
# 481                 hi      Chandni Chowk To China
# 585                 hi                        दंगल
# 627                 hi                         Fan
# 671                 hi             Anjaana Anjaani
# 695                 hi                   Tere Naam
# 771                 hi                     Kaminey
# 840                 hi                       नीरजा
# 848                 hi                    रान्झाना
# 970                 hi                   Heropanti
# 1004                hi                       Dabba
# 1491                hi                        Piku
# 1572                hi                     Ghajini
# 1640                hi          Bhaag Milkha Bhaag
# 1656                hi             Chennai Express
# 1694                hi                रमन राघव २.०
# 1719                hi                      Barfi!
# 1729                hi                      दिल से
# 1732                hi                 Grand Masti
# 1766                hi                     Tum Bin
# 1948                hi               मालामाल वीकली
# 1987                hi                 कल हो ना हो
# 1989                hi                      Sarkar
# 2239                hi                       धूम ३
# 2251                hi                   Bodyguard
# 2287                hi               बॉम्बे वेलवेट
# 2353                hi                Jodhaa Akbar
# 2390                hi               Khatta Meetha
# 2436                hi                Dear Zindagi
# 2480                hi                    Cocktail
# 2538                hi                        Josh
# 2563                hi          कभी अलविदा ना कहना
# 2567                hi              Gabbar Is Back
# 2807                hi                       Fanaa
# 2828                hi             Bajirao Mastani
# 2857                hi                 Madras Cafe
# 2859                hi                     Singham
# 2959                hi                  Jab We Met
#
#                                                overview  popularity  ...  \
# 3     Vidya Bagchi (Vidya Balan) arrives in Kolkata ...    3.174936  ...
# 213   Low-life thief Shiva and top-cop Vikram Rathor...    1.312833  ...
# 371   The film is about three husbands having affair...    1.417392  ...
# 401   The Legend of Bhagat Singh is a 2002 Indian hi...    0.904409  ...
# 419   Atithi Tum Kab Jaoge? is the story of Puneet a...    0.597058  ...
# 481   Based in Delhi's Chandni Chowk, orphaned Sidhu...    1.970481  ...
# 585   Dangal is an extraordinary true story based on...    8.792104  ...
# 627   The story of a fan whose world completely revo...    5.127876  ...
# 671   Akash (Ranbir Kapoor) and Kiara (Priyanka Chop...    1.822940  ...
# 695   Lower Caste Radhey Mohan is a no good slacker,...    1.280455  ...
# 771   Guddu and Charlie are identical twins born and...    2.089842  ...
# 840   Neerja is a portrayal on the life of the coura...    1.686250  ...
# 848   A small-town boy needs to break through the cl...    1.856101  ...
# 970   Rising from present India in the conflicting e...    2.031919  ...
# 1004  A mistaken delivery in Mumbai's famously effic...   10.766409  ...
# 1491  A road trip to Kolkata brings Piku, an archite...    2.942711  ...
# 1572  Sanjay a rich tycoon suffering from short term...    4.239080  ...
# 1640  The true story of the "Flying Sikh" world cham...    4.342418  ...
# 1656  Rahul embarks on a journey to a small town in ...    4.193560  ...
# 1694  Set in present day Mumbai the story follows th...    1.668794  ...
# 1719  He is cute. He's shrewd. The girls love him. T...    3.779077  ...
# 1729  The clash between love and ideology is portray...    1.891138  ...
# 1732  Amar, Prem and Meet are longtime friends who h...    1.250293  ...
# 1766  Shekhar, a businessman, accidentally kills his...    0.371679  ...
# 1948  Lilaram sells lottery tickets and one customer...    1.479018  ...
# 1987  Naina is a very serious girl with a very serio...    5.584308  ...
# 1989  The authority of a man, who runs a parallel go...    2.004745  ...
# 2239  To avenge his father's death, a circus enterta...    5.326716  ...
# 2251  Lovely Singh (Salman Khan) is the bodyguard of...    2.402032  ...
# 2287  An ordinary man, who goes against all odds to ...    1.377993  ...
# 2353  Jodhaa Akbar is a sixteenth century love story...   12.237488  ...
# 2390  Struggling road construction contractor, Sachi...    0.494047  ...
# 2436  An unconventional thinker (Shah Rukh Khan) hel...    3.699552  ...
# 2480  Gautam is an incorrigible flirt, who runs afte...    7.950488  ...
# 2538  Shah Rukh Khan and Sharad Kapoor are the leade...    4.031500  ...
# 2563  Dev and Maya are both married to different peo...    2.372520  ...
# 2567  A vigilante network taking out corrupt officia...    1.812728  ...
# 2807  Zooni Ali Beg (Kajol) is a blind Kashmiri girl...    3.003526  ...
# 2828  A historical account of the romance between th...    4.683689  ...
# 2857  An Indian Intelligence agent journeys into a w...    2.399890  ...
# 2859  A Bollywood classic directed by Rodit Shetty. ...    2.077410  ...
# 2959  Depressed after the passing of his father, Dha...    3.959411  ...
#
#      release_date runtime                                   spoken_languages  \
# 3          3/9/12   122.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 213        6/1/12   143.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 371        4/8/11   140.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 401        6/7/02   155.0  [{'iso_639_1': 'pa', 'name': 'ਪੰਜਾਬੀ'}, {'iso_...
# 419       2/26/10   155.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 481       1/16/09   149.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 585      12/23/16   161.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 627       4/15/16   142.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 671       9/24/10   151.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 695       8/15/03   132.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 771       8/14/09   135.0           [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# 840       2/19/16   122.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 848       6/21/13   140.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 970       5/23/14   146.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 1004      9/19/13   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 1491       5/8/15   123.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 1572     12/25/08   183.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 1640      7/12/13   186.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 1656       8/9/13   141.0  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...
# 1694      6/24/16   127.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 1719      9/14/12   155.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 1729      8/22/98   163.0  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...
# 1732      9/13/13   140.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 1766      7/13/01   158.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 1948      3/10/06   138.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 1987     11/27/03   186.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 1989       7/1/05   123.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 2239     12/18/13   172.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 2251      8/31/11   130.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 2287      5/15/15   151.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 2353      2/15/08   213.0  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...
# 2390      7/23/10   155.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 2436     11/24/16   149.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 2480      7/13/12   144.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 2538       6/9/00   162.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 2563      8/11/06   193.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2567       5/1/15   128.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 2807      5/26/06   168.0  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...
# 2828     12/18/15   150.0  [{'iso_639_1': 'de', 'name': 'Deutsch'}, {'iso...
# 2857      8/23/13   130.0            [{'iso_639_1': 'hi', 'name': 'हिन्दी'}]
# 2859      7/22/11   143.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2959     10/26/07   145.0  [{'iso_639_1': 'hi', 'name': 'हिन्दी'}, {'iso_...
#
#         status                                            tagline  \
# 3     Released                                                NaN
# 213   Released                                                NaN
# 371   Released  Husbands will say sorry ... Wives will say tha...
# 401   Released                                                NaN
# 419   Released                                                NaN
# 481   Released                                                NaN
# 585   Released                                                NaN
# 627   Released  World's biggest superstar got the universe's b...
# 671   Released  All the greatest love stories...are between st...
# 695   Released                    Unfortunately a true love story
# 771   Released             Thif monfoon. Difcover your mean fide.
# 840   Released                              Fear Gave Her Courage
# 848   Released                                                NaN
# 970   Released                                                NaN
# 1004  Released                                                NaN
# 1491  Released                               Motion Se Hi Emotion
# 1572  Released                                                NaN
# 1640  Released                   Now you will see his Real Story.
# 1656  Released                             Ready... Steady... Po!
# 1694  Released                                                NaN
# 1719  Released                                                NaN
# 1729  Released                                                NaN
# 1732  Released                            The Masti Boys are Back
# 1766  Released                             Love Will Find the Way
# 1948  Released                                                NaN
# 1987  Released                                                NaN
# 1989  Released                                                NaN
# 2239  Released                                                NaN
# 2251  Released                                                NaN
# 2287  Released                                                NaN
# 2353  Released                                                NaN
# 2390  Released                                                NaN
# 2436  Released                                                NaN
# 2480  Released  Sometimes good friends may be too good to shar...
# 2538  Released                                                NaN
# 2563  Released            A Love.... That Broke All Relationships
# 2567  Released                                                NaN
# 2807  Released                               Destroyed in love...
# 2828  Released                                                NaN
# 2857  Released                                Intercept the truth
# 2859  Released                                                NaN
# 2959  Released                                                NaN
#
#                                  title  \
# 3                              Kahaani
# 213                      Rowdy Rathore
# 371                          Thank You
# 401         The Legend of Bhagat Singh
# 419   Dear Guest, When Will You Leave?
# 481             Chandni Chowk To China
# 585                             Dangal
# 627                                Fan
# 671                    Anjaana Anjaani
# 695                          Tere Naam
# 771                            Kaminey
# 840                             Neerja
# 848                         Raanjhanaa
# 970                          Heropanti
# 1004                      The Lunchbox
# 1491                              Piku
# 1572                           Ghajini
# 1640                Bhaag Milkha Bhaag
# 1656                   Chennai Express
# 1694                  Raman Raghav 2.0
# 1719                             Barfi
# 1729                          Dil Se..
# 1732                       Grand Masti
# 1766                           Tum Bin
# 1948                   Malamaal Weekly
# 1987                     Kal Ho Naa Ho
# 1989                            Sarkar
# 2239                           Dhoom 3
# 2251                         Bodyguard
# 2287                     Bombay Velvet
# 2353                      Jodhaa Akbar
# 2390                     Khatta Meetha
# 2436                      Dear Zindagi
# 2480                          Cocktail
# 2538                              Josh
# 2563            Kabhi Alvida Naa Kehna
# 2567                    Gabbar Is Back
# 2807                             Fanaa
# 2828                   Bajirao Mastani
# 2857                       Madras Cafe
# 2859                           Singham
# 2959                        Jab We Met
#
#                                                Keywords  \
# 3     [{'id': 10092, 'name': 'mystery'}, {'id': 1054...
# 213   [{'id': 1721, 'name': 'fight'}, {'id': 8015, '...
# 371                                                 NaN
# 401                                                 NaN
# 419                                                 NaN
# 481   [{'id': 4344, 'name': 'musical'}, {'id': 10540...
# 585   [{'id': 5565, 'name': 'biography'}, {'id': 597...
# 627   [{'id': 1523, 'name': 'obsession'}, {'id': 981...
# 671   [{'id': 1252, 'name': 'suicide attempt'}, {'id...
# 695                                                 NaN
# 771                    [{'id': 14636, 'name': 'india'}]
# 840   [{'id': 4245, 'name': 'hijacking'}, {'id': 967...
# 848   [{'id': 10048, 'name': 'unrequited love'}, {'i...
# 970                                                 NaN
# 1004                                                NaN
# 1491                                                NaN
# 1572  [{'id': 331, 'name': 'tattoo'}, {'id': 154785,...
# 1640  [{'id': 795, 'name': 'running'}, {'id': 1721, ...
# 1656  [{'id': 4412, 'name': 'grandfather'}, {'id': 4...
# 1694  [{'id': 10024, 'name': 'psychopathic killer'},...
# 1719                   [{'id': 1646, 'name': 'autism'}]
# 1729  [{'id': 258, 'name': 'bomb'}, {'id': 321, 'nam...
# 1732                                                NaN
# 1766  [{'id': 128, 'name': 'love triangle'}, {'id': ...
# 1948                                                NaN
# 1987  [{'id': 242, 'name': 'new york'}, {'id': 958, ...
# 1989  [{'id': 417, 'name': 'corruption'}, {'id': 607...
# 2239  [{'id': 291, 'name': 'circus'}, {'id': 2492, '...
# 2251  [{'id': 2251, 'name': 'lie'}, {'id': 2913, 'na...
# 2287  [{'id': 1416, 'name': 'jazz'}, {'id': 2792, 'n...
# 2353  [{'id': 1157, 'name': 'wife husband relationsh...
# 2390  [{'id': 235064, 'name': 'remake of malayalam f...
# 2436                                                NaN
# 2480  [{'id': 6054, 'name': 'friendship'}, {'id': 97...
# 2538                                                NaN
# 2563  [{'id': 596, 'name': 'adultery'}, {'id': 34094...
# 2567                                                NaN
# 2807  [{'id': 1741, 'name': 'blindness and impaired ...
# 2828  [{'id': 232174, 'name': '–ª—é–±–æ–≤—å'}, {'id'...
# 2857  [{'id': 1990, 'name': 'cupboard'}, {'id': 5299...
# 2859  [{'id': 1721, 'name': 'fight'}, {'id': 13116, ...
# 2959  [{'id': 2038, 'name': "love of one's life"}, {...
#
#                                                    cast  \
# 3     [{'cast_id': 1, 'character': 'Vidya Bagchi', '...
# 213   [{'cast_id': 11, 'character': 'Shiva / Vikram ...
# 371   [{'cast_id': 1, 'character': 'Kishen', 'credit...
# 401   [{'cast_id': 12, 'character': 'Bhagat K. Singh...
# 419   [{'cast_id': 1, 'character': 'Puneet, Pappu', ...
# 481   [{'cast_id': 10, 'character': 'Sidhu', 'credit...
# 585   [{'cast_id': 0, 'character': 'Mahavir Singh Ph...
# 627   [{'cast_id': 1, 'character': 'Gaurav Chandna /...
# 671   [{'cast_id': 2, 'character': 'Kiara', 'credit_...
# 695   [{'cast_id': 3, 'character': 'Radhe Mohan', 'c...
# 771   [{'cast_id': 1, 'character': 'Charlie / Guddu'...
# 840   [{'cast_id': 0, 'character': 'Neerja Bhanot', ...
# 848   [{'cast_id': 1, 'character': 'Kundan', 'credit...
# 970   [{'cast_id': 1, 'character': 'Bablu', 'credit_...
# 1004  [{'cast_id': 2, 'character': 'Saajan Fernandes...
# 1491  [{'cast_id': 0, 'character': 'Bashkor Banerjee...
# 1572  [{'cast_id': 12, 'character': 'Sanjay Singhani...
# 1640  [{'cast_id': 1, 'character': 'Milkha Singh', '...
# 1656  [{'cast_id': 2, 'character': 'Rahul Mithaiwala...
# 1694  [{'cast_id': 6, 'character': 'Ramanna (Raman)'...
# 1719  [{'cast_id': 5, 'character': 'Jhilmil Singh', ...
# 1729  [{'cast_id': 2, 'character': 'Amarkanth Varma'...
# 1732  [{'cast_id': 2, 'character': 'Amar', 'credit_i...
# 1766  [{'cast_id': 1, 'character': 'Shekhar Malhotra...
# 1948  [{'cast_id': 1, 'character': 'Kanhaiya', 'cred...
# 1987  [{'cast_id': 8, 'character': 'Aman Mathur', 'c...
# 1989  [{'cast_id': 1, 'character': 'Subhash Nagre (S...
# 2239  [{'cast_id': 2, 'character': 'Sahir', 'credit_...
# 2251  [{'cast_id': 1, 'character': 'Lovely B. Singh'...
# 2287  [{'cast_id': 1, 'character': 'Rosie', 'credit_...
# 2353  [{'cast_id': 1, 'character': 'Jalaluddin Moham...
# 2390  [{'cast_id': 4, 'character': 'Sachin Tichkule'...
# 2436  [{'cast_id': 8, 'character': 'Kaira', 'credit_...
# 2480  [{'cast_id': 7, 'character': 'Veronica Malaney...
# 2538  [{'cast_id': 1, 'character': 'Max', 'credit_id...
# 2563  [{'cast_id': 1, 'character': 'Dev Saran', 'cre...
# 2567  [{'cast_id': 1, 'character': 'Professor Aditya...
# 2807  [{'cast_id': 4, 'character': 'Zooni Ali Beg', ...
# 2828  [{'cast_id': 1, 'character': 'Baji Rao I', 'cr...
# 2857  [{'cast_id': 2, 'character': 'Vikram Singh', '...
# 2859  [{'cast_id': 1, 'character': 'Bajirao Singham'...
# 2959  [{'cast_id': 9, 'character': 'Aditya Kashyap',...
#
#                                                    crew    revenue
# 3     [{'credit_id': '52fe48779251416c9108d6eb', 'de...   16000000
# 213   [{'credit_id': '52fe4a0bc3a36847f81b58a9', 'de...   31000000
# 371   [{'credit_id': '52fe4651c3a368484e08a13f', 'de...    4100000
# 401   [{'credit_id': '52fe44849251416c9101372f', 'de...    6000000
# 419   [{'credit_id': '5647c0359251413ade004b4d', 'de...    5000000
# 481   [{'credit_id': '52fe43d2c3a368484e00004d', 'de...    9400000
# 585   [{'credit_id': '5714ef3f92514146c80003ea', 'de...  310000000
# 627   [{'credit_id': '569bc0de9251415e7000003c', 'de...   29251596
# 671   [{'credit_id': '58a2fb2cc3a3682902007108', 'de...    5900000
# 695   [{'credit_id': '52fe491ec3a36847f8189cfb', 'de...          2
# 771   [{'credit_id': '52fe43f4c3a368484e007b65', 'de...   18130000
# 840   [{'credit_id': '5692588192514115bf001d11', 'de...    2978994
# 848   [{'credit_id': '52fe4c799251416c910f611d', 'de...   18000000
# 970   [{'credit_id': '53baa148c3a3685eb4006e29', 'de...   10000000
# 1004  [{'credit_id': '5476f65b9251415d7a0016eb', 'de...    4235151
# 1491  [{'credit_id': '5551de509251416a93005e01', 'de...   22159216
# 1572  [{'credit_id': '52fe45c99251416c75062659', 'de...   76000000
# 1640  [{'credit_id': '52fe4d1ac3a368484e1d74af', 'de...   25000000
# 1656  [{'credit_id': '581e56659251410f4f00f125', 'de...   62000000
# 1694  [{'credit_id': '57160f17c3a3682f450033eb', 'de...    1013926
# 1719  [{'credit_id': '5926294cc3a36877fd014ce9', 'de...    2804874
# 1729  [{'credit_id': '57b53e789251410918000155', 'de...   13000000
# 1732  [{'credit_id': '52fe4db49251416c7513dd27', 'de...   47000000
# 1766  [{'credit_id': '52fe46efc3a368484e0abfaf', 'de...    1486992
# 1948  [{'credit_id': '592dd1fbc3a36808c3000dd9', 'de...        204
# 1987  [{'credit_id': '52fe43b6c3a36847f8069c57', 'de...   13200241
# 1989  [{'credit_id': '576bae81c3a36864910013fc', 'de...    5900000
# 2239  [{'credit_id': '59488707c3a36816c504b523', 'de...   91000000
# 2251  [{'credit_id': '52fe48a1c3a368484e102d25', 'de...          8
# 2287  [{'credit_id': '57d00957c3a36866a400269f', 'de...    1500000
# 2353  [{'credit_id': '52fe45c99251416c75062761', 'de...   13000000
# 2390  [{'credit_id': '52fe468fc3a36847f8105a21', 'de...   10000000
# 2436  [{'credit_id': '57c6e9c3c3a3680ba4001c63', 'de...    3376375
# 2480  [{'credit_id': '52fe4bc8c3a36847f8213af9', 'de...   18800000
# 2538  [{'credit_id': '52fe4b82c3a368484e18c7f1', 'de...   15000000
# 2563  [{'credit_id': '52fe45ee9251416c75067637', 'de...   17000000
# 2567  [{'credit_id': '5792ff149251410d12008917', 'de...   41000000
# 2807  [{'credit_id': '52fe44aac3a36847f80a3315', 'de...   22175908
# 2828  [{'credit_id': '560b66e0c3a3686814004c7d', 'de...   56000000
# 2857  [{'credit_id': '52fe4e08c3a368484e20a8ed', 'de...    6500000
# 2859  [{'credit_id': '52fe4802c3a368484e0e513f', 'de...   25034000
# 2959  [{'credit_id': '537ef0d8c3a36805a1002844', 'de...    4600000
#
# [42 rows x 23 columns]

# %%
hindi_movie.to_csv("hindi_movie.csv")

# %% [markdown]
# ###Linear regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("/content/placement.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
df.columns
# Out:
# Index(['cgpa', 'package'], dtype='object')

# %%
plt.scatter(df["cgpa"],df["package"])
plt.xlabel("CGPA")
plt.ylabel("PACKAGE")
plt.show()

# %%
#find the null value
df.isnull().sum()
# Out:
# cgpa       0
# package    0
# dtype: int64

# %%
#find the independent and dependent feature
x = df.iloc[:,0]
y = df.iloc[:,1]
x
# Out:
# 0      6.89
# 1      5.12
# 2      7.82
# 3      7.42
# 4      6.94
#        ...
# 195    6.93
# 196    5.89
# 197    7.21
# 198    7.63
# 199    6.22
# Name: cgpa, Length: 200, dtype: float64

# %%
y
# Out:
# 0      3.26
# 1      1.98
# 2      3.25
# 3      3.67
# 4      3.57
#        ...
# 195    2.46
# 196    2.57
# 197    3.24
# 198    3.96
# 199    2.33
# Name: package, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.2,
                                                random_state = 42 )
x_train
# Out:
# 79     7.18
# 197    7.21
# 38     8.62
# 24     6.53
# 122    5.12
#        ...
# 106    6.13
# 14     7.73
# 92     7.90
# 179    7.14
# 102    5.13
# Name: cgpa, Length: 160, dtype: float64

# %%
#train the model
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr
# Out:
# LinearRegression()

# %%
#x_train = x_train.values.reshape(-1, 1)
#x_train
# Out:
# array([[7.18],
#        [7.21],
#        [8.62],
#        [6.53],
#        [5.12],
#        [6.93],
#        [7.15],
#        [7.48],
#        [4.85],
#        [7.61],
#        [5.84],
#        [6.75],
#        [7.89],
#        [5.91],
#        [7.12],
#        [8.44],
#        [7.91],
#        [7.69],
#        [6.93],
#        [7.11],
#        [9.31],
#        [5.98],
#        [8.1 ],
#        [8.94],
#        [6.87],
#        [7.39],
#        [5.95],
#        [8.11],
#        [7.11],
#        [5.64],
#        [9.26],
#        [6.78],
#        [5.53],
#        [6.89],
#        [7.4 ],
#        [6.94],
#        [8.31],
#        [7.19],
#        [7.95],
#        [5.42],
#        [7.82],
#        [8.99],
#        [6.07],
#        [6.26],
#        [7.28],
#        [4.79],
#        [7.3 ],
#        [5.99],
#        [6.19],
#        [5.48],
#        [6.14],
#        [6.76],
#        [6.71],
#        [6.35],
#        [6.61],
#        [7.89],
#        [8.71],
#        [6.73],
#        [5.42],
#        [5.23],
#        [6.94],
#        [6.96],
#        [6.93],
#        [5.84],
#        [7.77],
#        [6.17],
#        [5.32],
#        [6.34],
#        [8.58],
#        [6.07],
#        [8.6 ],
#        [6.89],
#        [7.63],
#        [7.94],
#        [5.79],
#        [5.1 ],
#        [7.36],
#        [5.09],
#        [8.93],
#        [5.94],
#        [9.38],
#        [7.76],
#        [6.98],
#        [7.38],
#        [7.28],
#        [6.19],
#        [7.88],
#        [5.66],
#        [6.1 ],
#        [7.43],
#        [8.65],
#        [5.84],
#        [5.83],
#        [7.08],
#        [7.66],
#        [7.91],
#        [7.42],
#        [6.66],
#        [6.47],
#        [6.05],
#        [6.19],
#        [8.15],
#        [6.31],
#        [8.87],
#        [7.63],
#        [7.34],
#        [6.75],
#        [8.18],
#        [6.22],
#        [8.44],
#        [6.29],
#        [8.22],
#        [6.42],
#        [6.09],
#        [6.93],
#        [7.56],
#        [8.01],
#        [6.37],
#        [5.38],
#        [7.78],
#        [7.04],
#        [7.2 ],
#        [8.13],
#        [7.28],
#        [9.16],
#        [6.86],
#        [6.33],
#        [9.58],
#        [5.89],
#        [6.92],
#        [8.63],
#        [4.73],
#        [6.85],
#        [6.6 ],
#        [7.13],
#        [8.25],
#        [7.29],
#        [5.9 ],
#        [6.47],
#        [4.57],
#        [5.12],
#        [8.37],
#        [8.28],
#        [6.68],
#        [6.12],
#        [7.05],
#        [6.61],
#        [9.04],
#        [8.09],
#        [6.85],
#        [6.5 ],
#        [6.22],
#        [7.28],
#        [7.35],
#        [7.47],
#        [6.13],
#        [7.73],
#        [7.9 ],
#        [7.14],
#        [5.13]])

# %%
lr.fit(x_train.values.reshape(-1, 1),y_train)
# Out:
# LinearRegression()

# %%
m = lr.coef_
m
# Out:
# array([0.57425647])

# %%
b = lr.intercept_
b
# Out:
# np.float64(-1.0270069374542108)

# %%
cgpa = 9.5
package = m*cgpa +b
print(package)
# Out:
# [4.42842955]
